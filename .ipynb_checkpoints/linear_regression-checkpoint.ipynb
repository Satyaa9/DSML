# %%
#imporint all things that needed
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as mlt

# %%
#Create sample Dataset 
data = {
    "Hours_Study" : [1,2,3,4,5],
    "Marks" : [50,55,65,70,80]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Hours_Study  Marks
# 0            1     50
# 1            2     55
# 2            3     65
# 3            4     70
# 4            5     80

# %%
#Seperate input(X) and output(Y)
X = df[["Hours_Study"]]    # independent variable
Y = df[["Marks"]]          # dependent variable

# %%
#Split Data into Training and Testing
X_train, X_test , Y_train , Y_test = train_test_split(
    X ,Y , test_size=0.2, random_state=42
)

# %%
#Train the Linear Regression Model
model = LinearRegression()
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
#Get Equation of Line
print("Slope (m):", model.coef_[0])  # slope calculate kela.
print("Intercept (b", model.intercept_)  # Intercept calculate kela.
# Out:
# Slope (m): [7.28571429]
# Intercept (b [42.57142857]

# %%
#Predict Values
Y_pred = model.predict(X_test)
print("Predicted value : ",Y_pred)
# Out:
# Predicted value :  [[57.14285714]]

# %%
#Calculate Error (MSE)
mse = mean_squared_error(Y_test,Y_pred)
print("Mean Squared Error :",mse)
# Out:
# Mean Squared Error : 4.59183673469389

# %%
mlt.scatter(X,Y)

# %%
## This data set dont have the correct shape values thats why we take a 
## another data set to draw a proper 
## we do the remaining operations in the other file .
