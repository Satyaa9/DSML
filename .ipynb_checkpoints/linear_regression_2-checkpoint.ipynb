# %%
# Importing all things that needed ... 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
# Dataset 
X = np.array([1,2,3,4]).reshape(-1,1)
Y = np.array([50,55,65,70])

# %%
# Model 
model = LinearRegression()

# %%
# Fiting the model 
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Prediction
Y_predicted = model.predict(X)

# %%
# Slope and Intercept 
print("Slope",model.coef_[0])
print("Intercept",model.intercept_)
# Out:
# Slope 7.000000000000003
# Intercept 42.49999999999999

# %%
# Plotting 
plt.scatter(X,Y,color="blue",label="Actual marks")
plt.plot(X,Y_predicted,color="red",label="Regression line (Best Fit)")
plt.xlabel("Hours")
plt.ylabel("Exam Marks")
plt.title("Linear Regression")
# Out:
# Text(0.5, 1.0, 'Linear Regression')
